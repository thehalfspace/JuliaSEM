# %% [markdown]
# <h1><center> Benchmark Problem

# %%
@time include("src/setup.jl")
# Out:
# Total number of nodes on fault = 241
# Average node spacing = 200.0
# dt = 0.01302220036513943
# WARNING: redefining constant Vo
# WARNING: redefining constant xLf
# WARNING: redefining constant FltZ
# WARNING: redefining constant FltX
# Setup Complete
#   4.679389 seconds (7.08 M allocations: 1.158 GiB, 8.05% gc time)
# WARNING: redefining constant iFBC
# WARNING: redefining constant FltIglobBC

# %%
@time include("src/timesolver.jl")
# Out:
# Time (yr) = 3.5809e-07
# Time (yr) = 5.6456e-07
# Time (yr) = 7.7102e-07
# Time (yr) = 9.7749e-07
# Time (yr) = 1.184e-06
# Time (yr) = 1.3904e-06
# Time (yr) = 1.5969e-06
# Time (yr) = 1.8034e-06
# Time (yr) = 2.0098e-06
# Time (yr) = 2.2163e-06
# Time (yr) = 2.4227e-06
# Time (yr) = 2.6292e-06
# Time (yr) = 2.8357e-06
# Time (yr) = 3.0421e-06
# Time (yr) = 3.2486e-06
# Time (yr) = 3.4551e-06
# Time (yr) = 0.0001033
# Time (yr) = 1.8962
# Time (yr) = 8.7455
# Time (yr) = 15.595
# Time (yr) = 22.444
# Time (yr) = 29.293
# Time (yr) = 36.143
# Time (yr) = 42.992
# Time (yr) = 49.841
# Time (yr) = 56.598
# Time (yr) = 63.447
# Time (yr) = 70.296
# Time (yr) = 76.644
# Time (yr) = 83.285
# Time (yr) = 90.134
# Time (yr) = 96.983
# Time (yr) = 102.23
# Time (yr) = 102.23
# Time (yr) = 102.23
# Time (yr) = 102.23
# Time (yr) = 102.23
# Time (yr) = 102.24
# Time (yr) = 106.59
# Time (yr) = 113.44
# Time (yr) = 120.29
# Time (yr) = 127.14
# Time (yr) = 133.99
# Time (yr) = 140.84
# Time (yr) = 147.68
# Time (yr) = 154.53
# Time (yr) = 161.38
# Time (yr) = 168.23
# Time (yr) = 175.08
# Time (yr) = 181.93
# Time (yr) = 187.27
# Time (yr) = 193.97
# Time (yr) = 200.82
# Time (yr) = 207.67
# Time (yr) = 214.52
# Time (yr) = 220.44
# Time (yr) = 220.44
# Time (yr) = 220.44
# Time (yr) = 220.44
# Time (yr) = 220.44
# Time (yr) = 220.44
# Time (yr) = 220.44
# Time (yr) = 221.73
# Time (yr) = 228.57
# Time (yr) = 235.42
# Time (yr) = 242.27
# Time (yr) = 249.12
# Time (yr) = 255.97
# Time (yr) = 262.82
# Time (yr) = 269.67
# Time (yr) = 276.52
# Time (yr) = 283.37
# Time (yr) = 290.22
# Time (yr) = 297.07
# Simulation Complete
# 1582.217154 seconds (7.03 G allocations: 2.627 TiB, 12.83% gc time)

# %% [markdown]
# <h3> Save workspace variables to file

# %%
using JLD

@save "data/benchmark/test01.jld"

# %%
include("plots.jl")
# Out:
# cumSlip (generic function with 1 method)

# %%
slipvelPlot(SlipVel, time_, yr2sec)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
stressPlot(Stress, time_, yr2sec)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
cumSlip(delfsec, delf5yr, FltX)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
fricPlot(cca, ccb, FltX)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
