# %% [markdown]
# <h1><center> Benchmark Problem

# %%
@time include("src/setup.jl")
# Out:
# Total number of nodes on fault = 961
# Average node spacing = 50.0
# WARNING: redefining constant NelX
# WARNING: redefining constant NelY
# WARNING: redefining constant Nel
# WARNING: redefining constant P
# WARNING: redefining constant NGLL
# WARNING: redefining constant FaultNglob
# WARNING: redefining constant Vo
# WARNING: redefining constant xLf
# WARNING: redefining constant nglob
# WARNING: redefining constant dx_dxi
# WARNING: redefining constant dy_deta
# WARNING: redefining constant jac
# WARNING: redefining constant FltZ
# WARNING: redefining constant FltX

# %%
@time include("src/timesolver.jl")
# Out:
# Time (yr) = 2.9328e-07
# Time (yr) = 4.4813e-07
# Time (yr) = 6.0298e-07
# Time (yr) = 7.5783e-07
# Time (yr) = 9.1268e-07
# Time (yr) = 1.0675e-06
# Time (yr) = 1.2224e-06
# Time (yr) = 1.3772e-06
# Time (yr) = 1.5321e-06
# Time (yr) = 1.6869e-06
# Time (yr) = 1.8418e-06
# Time (yr) = 1.9966e-06
# Time (yr) = 2.1515e-06
# Time (yr) = 2.3063e-06
# Time (yr) = 2.4612e-06
# Time (yr) = 2.616e-06
# Time (yr) = 2.7709e-06
# Time (yr) = 2.9257e-06
# Time (yr) = 3.0806e-06
# Time (yr) = 3.2354e-06
# Time (yr) = 3.3903e-06
# Time (yr) = 3.5451e-06
# Time (yr) = 3.7e-06
# Time (yr) = 3.8548e-06
# Time (yr) = 4.0097e-06
# Time (yr) = 4.1645e-06
# Time (yr) = 4.3194e-06
# Time (yr) = 4.4742e-06
# Time (yr) = 4.6291e-06
# Time (yr) = 4.7839e-06
# Time (yr) = 4.9388e-06
# Time (yr) = 5.0936e-06
# Time (yr) = 5.2485e-06
# Time (yr) = 5.4033e-06
# Time (yr) = 5.5582e-06
# Time (yr) = 5.713e-06
# Time (yr) = 5.8679e-06
# Time (yr) = 6.0227e-06
# Time (yr) = 6.1775e-06
# Time (yr) = 6.3324e-06
# Time (yr) = 6.4872e-06
# Time (yr) = 6.6421e-06
# Time (yr) = 6.7969e-06
# Time (yr) = 6.9518e-06
# Time (yr) = 7.1066e-06
# Time (yr) = 7.2615e-06
# Time (yr) = 7.4163e-06
# Time (yr) = 7.5712e-06
# Time (yr) = 7.726e-06
# Time (yr) = 7.8809e-06
# Time (yr) = 8.0357e-06
# Time (yr) = 8.1906e-06
# Time (yr) = 2.3226e-05
# Time (yr) = 0.0014252
# Time (yr) = 0.026954
# Time (yr) = 0.53647
# Time (yr) = 8.4843
# Time (yr) = 31.339
# Time (yr) = 46.755
# Time (yr) = 83.022
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.367
# Time (yr) = 95.496
# Time (yr) = 107.35
# Time (yr) = 149.64
# Time (yr) = 187.82
# Time (yr) = 190.44
# Time (yr) = 190.44
# Time (yr) = 190.44
# Time (yr) = 190.44
# Time (yr) = 190.44
# Time (yr) = 190.44
# Time (yr) = 190.44
# Time (yr) = 190.44
# Time (yr) = 198.09
# Time (yr) = 252.46
# Time (yr) = 291.84
# Simulation Complete
# 5647.915603 seconds (21.44 G allocations: 7.312 TiB, 23.40% gc time)

# %% [markdown]
# <h3> Save workspace variables to file

# %%
using JLD

@save "data/benchmark/bm01.jld"

# %%
include("plots.jl")
# Out:
# cumSlip (generic function with 1 method)

# %%
slipvelPlot(SlipVel, time_, yr2sec)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
stressPlot(Stress, time_, yr2sec)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
cumSlip(delfsec, delf5yr, FltX)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
fricPlot(cca, ccb, FltX)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plot(Seff)
show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
