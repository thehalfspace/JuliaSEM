# %% [markdown]
# <h1><center> Benchmark Problem

# %%
@time include("src/setup.jl")
# Out:
# Total number of nodes on fault = 121
# Average node spacing = 500.0
# dt = 0.05383574417369871
# WARNING: redefining constant Vo
# WARNING: redefining constant xLf
# WARNING: redefining constant FltZ
# WARNING: redefining constant FltX
# Setup Complete
#   2.175279 seconds (2.55 M allocations: 538.730 MiB, 12.17% gc time)
# WARNING: redefining constant iFBC
# WARNING: redefining constant FltIglobBC

# %%
include("plots.jl")
# Out:
# 114

# %%
fricPlot(cca, ccb, FltX)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
tauo
# Out:
# 121-element Array{Float64,1}:
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  ⋮
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
#  4.38155e7
