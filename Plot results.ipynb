# %% [markdown]
# <h1><center> Simulation results

# %%
using JLD
using PyPlot

# %%
@load "data/testing/test02.jld";

# %% [markdown]
# <h3> Plot friction parameters

# %%
# Plot rate and state friction parameters
plot(cca, FltX/1e3, "b-")
plot(ccb, FltX/1e3, "r-")
plot(cca-ccb, FltX/1e3, "k-")
plot(repmat([0], FaultNglob), FltX/1e3, "b--")
ylim([-40, 0])
show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
repmat([0], FltX)
# Out:
# MethodError: no method matching repmat(::Array{Int64,1}, ::Array{Float64,1})
# Closest candidates are:
#   repmat(::AbstractArray{T,1} where T, ::Int64) at abstractarraymath.jl:319
#   repmat(::Union{AbstractArray{T,1}, AbstractArray{T,2}} where T, ::Int64) at abstractarraymath.jl:305
#   repmat(::Union{AbstractArray{T,1}, AbstractArray{T,2}} where T, ::Int64, ::Int64) at abstractarraymath.jl:305
#   ...
#
# Stacktrace:
#  [1] include_string(::String, ::String) at ./loading.jl:515

# %% [markdown]
# <h3> Plot Cumulative Slip

# %%
plot(delf5yr, FltX/1e3, linewidth=0.5, color="blue")
plot(delfsec, FltX/1e3, linewidth=0.5, color="red")
ylim((-24, 0))
show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
Pkg.build("Homebrew")
# Out:
# INFO: Building Homebrew
# Error: git: /Users/prithvithakur/.julia/v0.6/Homebrew/deps/usr/Library/Taps/homebrew/homebrew-core/Formula/git.rb:192: syntax error, unexpected $undefined, expecting keyword_end
#       \thelper = osxkeychain
#        ^
# ==============================[ ERROR: Homebrew ]===============================
#
# LoadError: ArgumentError: `brew info` failed for String["git"]!
# while loading /Users/prithvithakur/.julia/v0.6/Homebrew/deps/build.jl, in expression starting on line 2
#
# ...
#
# ================================[ BUILD ERRORS ]================================
#
# WARNING: Homebrew had build errors.
#
#  - packages with build errors remain installed in /Users/prithvithakur/.julia/v0.6
#  - build the package(s) and all dependencies with `Pkg.build("Homebrew")`
#  - build a single package by running its `deps/build.jl` script
#
# ...
